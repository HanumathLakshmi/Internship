# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://en.wikipedia.org/wiki/Main_Page')
bs = BeautifulSoup(html, "html.parser")
titles = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('List all the header tags :', *titles, sep='\n\n')
# Out:
# List all the header tags :
#
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none"><span class="mw-page-title-main">Main Page</span></h1>
#
# <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfl-h2"><span id="From_today.27s_featured_list"></span><span class="mw-headline" id="From_today's_featured_list">From today's featured list</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>
#
# <h2 class="mp-h2" id="mp-lang"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>

# %%
from bs4 import BeautifulSoup
import requests


def Menu():
	print('\n1. Men \n2. Women\n')
	gen=Gender()
	print('\n1. Team Rankings \n2. Player Ranking\n')
	tp=TeamOrPlayer()

	mode=''
	val=''

	if gen=='mens':
		print('\n1. Test\n2. ODI\n3. T20\n')
		mode=Mode()

	if tp=='player-rankings':
		if mode=='':
			print('\n1. ODI\n2. T20\n')
			mode=Mode2()
		print('\n1. Batting\n2. Bowling\n3. All-Rounder\n')
		val=Value()

	return gen,tp,mode,val


def Gender():
	gender=input('Enter you choice:')
	code={'1':'mens','2':'womens'}

	if gender in code:
		return code[gender]

	else:
		print('\nInvalid Input\nTry Again\n')
		return Gender();


def TeamOrPlayer():
	choice=input('Enter your choice:')
	tp={'1':'team-rankings','2':'player-rankings'}

	if choice in tp:
		return tp[choice]

	else:
		print('\nInvalid Input\nTry Again\n')
		return TeamOrPlayer();


def Mode():
	choice=input('Enter your choice:')
	word={'1':'/test','2':'/odi','3':'/t20i'}

	if choice in word:
		return word[choice]

	else:
		print('\nInvalid Input\nTry Again\n')
		return Choice();


def Mode2():
	choice=input('Enter your choice:')
	word={'1':'/odi','2':'/t20i'}

	if choice in word:
		return word[choice]

	else:
		print('\nInvalid Input\nTry Again\n')
		return Choice();


def Value():
	choice=input('Enter your choice:')
	val={'1':'batting','2':'bowling','3':'all-rounder'}

	if choice in val:
		return val[choice]

	else:
		print('\nInvalid Input\nTry Again\n')
		return Value()


def URL():
	gen,tp,mode,val=Menu()
	url='https://www.icc-cricket.com/rankings/'+gen+'/'+tp+mode+'/'+val
	header=gen.upper() +' ' +mode[1:].upper() + ' ' + val.upper()
	print('\n{:<15}  {:<30}\n{:<15}  {:<30}'.format('',tp.upper(),'',header))
	return url,tp


def SOUP(url,tp):
	try:
		res=requests.get(url)
		soup=BeautifulSoup(res.text,'lxml')
		a= soup.find_all('tr',{'class':'table-body'})
		data={}

		for i in a :
			team=[]
			name=''
			rating=''

			try:
				rank=int(i.contents[1].text)
			except:
				pass

			try:	
				name=i.contents[3].text.replace('\n','')
				name=" ".join(name.split())
				if rank==1 and tp=='player-rankings':
					name=name[0:-3]
			except:
				pass

			try:
				rating=i.contents[9].text
			except:
				if rank==1 :
					rating=i.contents[5].text
				else:
					rating=i.contents[7].text

			team.extend([name,rating])
			data[rank]=team

		return data

	except:
		return SOUP(url,tp)


def Print(data):
	print('\nRANKING \t TEAM \t\t\t  RATING')
	for i in sorted(data):
		print('{:<10}       '.format(i),end='')
		for j in range(len(data[i])):
			print('{:<20}'.format(data[i][j]),end='     ')
		print()


def main():

	url,tp=URL()
	data=SOUP(url,tp)
	Print(data)	




if __name__=='__main__':
	main()
# Out:
# 1. Men
# 2. Women
#
# Enter you choice:1
#
# 1. Team Rankings
# 2. Player Ranking
#
# Enter your choice:
#
# Invalid Input
# Try Again
#
# Enter your choice:1
#
# 1. Test
# 2. ODI
# 3. T20
#
# Enter your choice:2
#
#                  TEAM-RANKINGS
#                  MENS ODI
#
# RANKING 	 TEAM 			  RATING
# 2                PakistanPAK              116
# 3                IndiaIND                 115
# 4                New ZealandNZ            104
# 5                EnglandENG               101
# 6                South AfricaSA           101
# 7                BangladeshBAN            98
# 8                AfghanistanAFG           88
# 9                Sri LankaSL              80
# 10               West IndiesWI            72
# 11               ZimbabweZIM              51
# 12               IrelandIRE               46
# 13               ScotlandSCO              46
# 14               NepalNEP                 37
# 15               United StatesUSA         35
# 16               NamibiaNAM               29
# 17               NetherlandsNED           26
# 18               OmanOMA                  20
# 19               UAEUAE                   18
# 20               Papua New GuineaPNG      4

# %%
import requests
from bs4 import BeautifulSoup

url='https://www.bbc.com/news'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')
headlines = soup.find('body').find_all('h3')
for x in headlines:
    print(x.text.strip())
# Out:
# US distances itself from Russia incursion claim
# US distances itself from Russia incursion claim
# Racism furore reignites scrutiny of Australian media
# India and Australia announce migration deal
# Watch brazen jewellery heist by disguised gunmen
# Is this batter Indian cricket's next big thing?
# Poison and sabotage: South Africa's power problem
# Apple strikes major US-made chip deal
# Can China overtake the US in the AI marathon?
# Woman hit by royal police escort motorbike dies
# Trump rival to launch 2024 candidacy on Twitter
# Target removes some LGBTQ products after threats
# Trump rival to launch 2024 candidacy on Twitter
# Target removes some LGBTQ products after threats
# Honda to return to F1 as Aston Martin engine partner
# Last known Taiwanese 'comfort woman' dies at 92
# What to know about the Canada-China meddling row
# Indian wrestlers risk Olympic dream for '#MeToo' protest
# BBC World News TV
# BBC World Service Radio
# 365 days after the Uvalde school shooting
# Ray Stevenson's film and TV career in pictures
# Cowboy wrangles runaway cow on US highway
# Escaped water buffalo herd wreck new swimming pool
# Why car parks are the hottest space in solar power
# Risk and reward as DeSantis links arms with Musk
# Who is Florida's first lady Casey DeSantis?
# How bingo is bouncing back to a full house
# Vinicius case opens wider racism debate in Spain
# Who are the fighters infiltrating Russia from Ukraine?
# Who is the Florida governor Ron DeSantis?
# Intercepting Russian 'Zombies' at a Nato airbase
# Why NYC is sinking under its own weight
# How embracing AI gets workers ahead
# The BBQ town luring millions
# The 100 greatest children's books ever
# The 'flawed' skill that shaped history
# Is talent or hard work more important?
# The Dutch solution to stress
# News daily newsletter
# Mobile app
# Get in touch

# %%
https://www.dineout.co.in/bangalore-restaurants

This application uses django 1.11.14, python 3 and Beautiful Soup 4.

Installing django 1.11 on Linux

Install Python 3

Set up virtualenv and install Django

$ python3 -m venv myvenv
$ source myvenv/bin/activate

$ python3 -m pip install --upgrade pip
$ pip install django==1.11

Installing Beautiful Soup

$ pip install beautifulsoup4

Running the app 'restaurant'

$ python manage.py runserver
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_3212\2317057645.py", line 1
#     https://www.dineout.co.in/bangalore-restaurants
#           ^
# SyntaxError: invalid syntax
